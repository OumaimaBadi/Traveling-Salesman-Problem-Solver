# %%
import csv

liste=[]
# ouverture en lecture du fichier csv
with open('Instance_1.csv', newline='') as fichier:
    # on crée un objet reader
    lecture = csv.reader(fichier, delimiter=',')
    # lecture et affichage des lignes:
    for ligne in lecture:
        liste.append(list(map(int,(ligne))))

# %%
import sys
import copy


all_sets = []
g = {}
p = []

def main():
    for x in range(1, n):
        g[x + 1, ()] = liste[x][0]

    get_minimum(s, l)
    print('\n\nSolution to TSP: { ',s,',', end='')
    solution = p.pop()
    print(solution[1][0], end=', ')
    for x in range(n - 2):
        for new_solution in p:
            if tuple(solution[1]) == new_solution[0]:
                solution = new_solution
                print(solution[1][0], end=', ')
                break
    print(s,' }')
    return


def get_minimum(k, a):
    if (k, a) in g:
        
        return g[k, a]
    values = []
    all_min = []
    for j in a:
        set_a = copy.deepcopy(list(a))
        set_a.remove(j)
        all_min.append([j, tuple(set_a)])
        result = get_minimum(j, tuple(set_a))
        values.append(liste[k-1][j-1] + result)    

    g[k, a] = min(values)
    p.append(((k, a), all_min[values.index(g[k, a])]))

    return g[k, a]





s =int(input("donner la ville de départ : "))
n= int(input("donner la taille de la matrice : "))
l=()
for i in range(1,n+1):
    if i==s:
        continue
    else:
        l+=i,
        
import time
tps1 = time.time()
res = main()
print(get_minimum(s,l))
tps2 = time.time()
print(tps2 - tps1)
